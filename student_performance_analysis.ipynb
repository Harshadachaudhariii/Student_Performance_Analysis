# %% [markdown]
# ## Student Performance

# %% [markdown]
# The dataset is related to student performance and attributes in secondary education. Here's a general introduction based on the columns present in the DataFrame:
#
# This dataset contains information about students in secondary education, including demographic details, family background, educational support, lifestyle choices, and academic performance. Each row represents a unique student, and the columns provide various attributes and characteristics associated with them.

# %% [markdown]
# Dataset contains following columns:
# 1. school: School attended by the student.
# 2. sex: Student's gender (male or female).
# 3. age: Student's age.
# 4. address: Type of address of the student (urban or rural).
# 5. famsize: Family size (binary categorization: "LE3" - less or equal to 3 or "GT3" - greater than 3).
# 6. Pstatus: Parent's cohabitation status (living together or apart).
# 7. Medu: Mother's education level (0 to 4, representing none to higher education).
# 8. Fedu: Father's education level (0 to 4, representing none to higher education).
# 9. Mjob: Mother's occupation.
# 10. Fjob: Father's occupation.
# 11. reason: Reason for choosing the school.
# 12. guardian: Student's guardian.
# 13. traveltime: Travel time to school.
# 14. studytime: Weekly study time (hours).
# 15. failures: Number of past class failures.
# 16. schoolsup: Extra educational support at school (yes or no).
# 17. famsup: Family educational support (yes or no).
# 18. paid: Extra paid classes within the course subject (yes or no).
# 19. activities: Extra-curricular activities (yes or no).
# 20. nursery: Attended nursery school (yes or no).
# 21. higher: Wants to take higher education (yes or no).
# 22. internet: Internet access at home (yes or no).
# 23. romantic: In a romantic relationship (yes or no).
# 24. famrel: Quality of family relationships (from 1 - very bad to 5 - excellent).
# 25. freetime: Free time after school (from 1 - very low to 5 - very high).
# 26. goout: Going out with friends (from 1 - very low to 5 - very high).
# 27. Dalc: Workday alcohol consumption (from 1 - very low to 5 - very high).
# 28. Walc: Weekend alcohol consumption (from 1 - very low to 5 - very high).
# 29. health: Current health status (from 1 - very bad to 5 - very good).
# 30. absences: Number of school absences.
# 31. G1: First period grade (from 0 to 20).
# 32. G2: Second period grade (from 0 to 20).
# 33. G3: Final grade (from 0 to 20).

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt


import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv("student-por.csv")
data
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 644     MS   F   19       R     GT3       T     2     3  services     other
# 645     MS   F   18       U     LE3       T     3     1   teacher  services
# 646     MS   F   18       U     GT3       T     1     1     other     other
# 647     MS   M   17       U     LE3       T     3     1  services  services
# 648     MS   M   18       R     LE3       T     3     2  services     other
#
# ...

# %%
data.head(5)
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        4   0  11  11
# 1      5        3      3     1     1      3        2   9  11  11
# 2      4        3      2     2     3      3        6  12  13  12
# 3      3        2      2     1     1      5        0  14  14  14
# 4      4        3      2     1     2      5        0  11  13  13
#
# [5 rows x 33 columns]

# %%
data.tail(5)
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 644     MS   F   19       R     GT3       T     2     3  services     other
# 645     MS   F   18       U     LE3       T     3     1   teacher  services
# 646     MS   F   18       U     GT3       T     1     1     other     other
# 647     MS   M   17       U     LE3       T     3     1  services  services
# 648     MS   M   18       R     LE3       T     3     2  services     other
#
#      ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 644  ...      5        4      2     1     2      5        4  10  11  10
# 645  ...      4        3      4     1     1      1        4  15  15  16
# 646  ...      1        1      1     1     1      5        6  11  12   9
# 647  ...      2        4      5     3     4      2        6  10  10  10
# 648  ...      4        4      1     3     4      5        4  10  11  11
#
# [5 rows x 33 columns]

# %%
data.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %%
data.shape
# Out:
# (649, 33)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 649 entries, 0 to 648
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      649 non-null    object
#  1   sex         649 non-null    object
#  2   age         649 non-null    int64
#  3   address     649 non-null    object
#  4   famsize     649 non-null    object
#  5   Pstatus     649 non-null    object
#  6   Medu        649 non-null    int64
#  7   Fedu        649 non-null    int64
#  8   Mjob        649 non-null    object
#  9   Fjob        649 non-null    object
#  10  reason      649 non-null    object
#  11  guardian    649 non-null    object
#  12  traveltime  649 non-null    int64
#  13  studytime   649 non-null    int64
#  14  failures    649 non-null    int64
#  15  schoolsup   649 non-null    object
#  16  famsup      649 non-null    object
#  17  paid        649 non-null    object
#  18  activities  649 non-null    object
# ...

# %%
data.isnull().sum()
# Out:
# studytime     0
# failures      0
# schoolsup     0
# famsup        0
# paid          0
# activities    0
# nursery       0
# higher        0
# internet      0
# romantic      0
# famrel        0
# freetime      0
# goout         0
# Dalc          0
# Walc          0
# health        0
# absences      0
# G1            0
# G2            0
# G3            0
# dtype: int64

# %%
#there are no null values in the dataset

# %%
#Univariate analysis
data['school'].value_counts(normalize=True)
# Out:
# school
# GP    0.651772
# MS    0.348228
# Name: proportion, dtype: float64

# %%
plt.figure(figsize=(8,5))
sns.countplot(x = 'school', data=data, palette='pastel')
plt.title('Dist of schools')
plt.xlabel("School")
plt.ylabel("Count")

plt.show()

# %%
#GP has higher no of students

# %%
sns.histplot(data['age'], bins=10, kde=True, color='purple')
plt.show()

# %%
#Most of the students are in the age group 16-17
# skewed distribution

# %%
sns.countplot(x ='address', data = data, palette='dark' )
plt.show()

# %%
#The majority of students comes from urban region

# %%
data['reason'].value_counts()
# Out:
# reason
# course        285
# home          149
# reputation    143
# other          72
# Name: count, dtype: int64

# %%
reason = data['reason'].value_counts()
plt.pie(reason, labels=reason.index, autopct='%1.1f%%')
plt.show()

# %%
#common reason >>  to join the course

# %%
act = data.activities.value_counts()
plt.pie(act, labels = act.index, autopct='%1.1f%%')
plt.show()

# %%
#48.5% are praticipating
data.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %%
walc = data['Walc'].value_counts()
walc
# Out:
# Walc
# 1    247
# 2    150
# 3    120
# 4     87
# 5     45
# Name: count, dtype: int64

# %%
#insighhts >> 45 studentes have regular weekend alcohal consumption

# %%
plt.pie(walc, labels=walc.index, autopct="%1.1f%%")
plt.show()

# %%
dalc = data['Dalc'].value_counts()
dalc
plt.pie(dalc, labels=walc.index, autopct="%1.1f%%")
plt.show()

# %%
#Bivariate analysis

# %%
data
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 644     MS   F   19       R     GT3       T     2     3  services     other
# 645     MS   F   18       U     LE3       T     3     1   teacher  services
# 646     MS   F   18       U     GT3       T     1     1     other     other
# 647     MS   M   17       U     LE3       T     3     1  services  services
# 648     MS   M   18       R     LE3       T     3     2  services     other
#
# ...

# %%
plt.figure(figsize=(12,6))
plt.subplot(1,2,1)
sns.countplot(x='Medu', data= data, palette='Set2')
plt.xlabel("Mother education level")
plt.ylabel("count")
plt.title("Mother education level distribtion")

plt.subplot(1,2,2)
sns.countplot(x ='Fedu', data=data, palette='Set2')
plt.xlabel("Father education level")
plt.ylabel("count")
plt.title("Father education level distribtion")
plt.show()

# %%
#insights >> mothers are mode educated in terms of higher education as compared to fathers

# %%
sns.barplot(x ='studytime', y ='G3', data=data, color='red')
plt.show()

# %%
sns.barplot(x ='studytime', y ='G2', data=data, color='purple')
plt.show()

# %%
#Insight>>if a student study for an hour than the marks scored on an average  is 11
#if a student study for two hours than the marks scored on an average  is 12

# %%
sns.barplot(x = 'internet', y = 'G3', data=data, palette='dark')
plt.show()

# %%
#insights>> on an avg students using internet is getting a score of 12

# %%
#multivariate analysis
sns.barplot(x = 'sex', y = 'G3', hue = 'address', data=data, palette = 'Set2')
# Out:
# <Axes: xlabel='sex', ylabel='G3'>

# %%
#insights>> noth urban males and females are getting higher average marks

# %%
num_cols = ['age', 'traveltime', 'studytime', 'absences', 'G1', 'G2', 'G3']

sns.boxplot(data = data[num_cols], palette = 'Set2')
# Out:
# <Axes: >

# %%
#insights>> median age is 17
#median marks for g1 and g3 are same
#there are some outliers

# %%
corr = data.corr(numeric_only = True)
corr
# Out:
#                  age      Medu      Fedu  traveltime  studytime  failures  \
# age         1.000000 -0.107832 -0.121050    0.034490  -0.008415  0.319968
# Medu       -0.107832  1.000000  0.647477   -0.265079   0.097006 -0.172210
# Fedu       -0.121050  0.647477  1.000000   -0.208288   0.050400 -0.165915
# traveltime  0.034490 -0.265079 -0.208288    1.000000  -0.063154  0.097730
# studytime  -0.008415  0.097006  0.050400   -0.063154   1.000000 -0.147441
# failures    0.319968 -0.172210 -0.165915    0.097730  -0.147441  1.000000
# famrel     -0.020559  0.024421  0.020256   -0.009521  -0.004127 -0.062645
# freetime   -0.004910 -0.019686  0.006841    0.000937  -0.068829  0.108995
# goout       0.112805  0.009536  0.027690    0.057454  -0.075442  0.045078
# Dalc        0.134768 -0.007018  0.000061    0.092824  -0.137585  0.105949
# Walc        0.086357 -0.019766  0.038445    0.057007  -0.214925  0.082266
# health     -0.008750  0.004614  0.044910   -0.048261  -0.056433  0.035588
# ...

# %%
plt.figure(figsize = (12, 10))
sns.heatmap(corr, annot=True, cmap = "coolwarm", fmt = ".2f")
plt.show()

# %%
#strongs positive correlations, strong negative correlations

# %%
students_grades_df = data.copy()
students_grades_df
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 644     MS   F   19       R     GT3       T     2     3  services     other
# 645     MS   F   18       U     LE3       T     3     1   teacher  services
# 646     MS   F   18       U     GT3       T     1     1     other     other
# 647     MS   M   17       U     LE3       T     3     1  services  services
# 648     MS   M   18       R     LE3       T     3     2  services     other
#
# ...

# %%
#Q1-1.5*IQR
#Q3+1.5*IQR

# %%
def detect_outliers(columns):
    outlier_indices = []
    for column in columns:
        Q1 = students_grades_df[column].quantile(0.25)
        Q3 = students_grades_df[column].quantile(0.75)
        IQR = Q3 - Q1
        
        #mask is a boolean condition
        mask =(students_grades_df[column] >= (Q1-1.5*IQR)) & (students_grades_df[column] <= (Q3+1.5*IQR))
        mask = mask.to_numpy() #bool to numpy array
        
        #find the indices of values that do not satisfy the mask condition>> that will be outlier
        false_indice = np.argwhere(~mask)
        outlier_indices.append(false_indice)
    return np.unique(np.concatenate(outlier_indices).ravel())

#np.concatenate(outlier_indices)>> combine all the outlier index arrays into a single array
#so each column will have one array
#.ravel>> flattens the multi-dimensional array into 1 d array

# %%
num_cols = ["age", "absences"]
print(detect_outliers(num_cols))
# Out:
# [ 40 103 150 155 161 197 206 211 212 217 230 253 254 256 263 279 311 325
#  326 397 405 413]

# %%
#considering absences as the target variable
X, y = students_grades_df.iloc[:, :-1], students_grades_df.iloc[:, -1]
